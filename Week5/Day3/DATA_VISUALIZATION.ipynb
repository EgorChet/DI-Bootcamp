# %% [markdown]
# # DATA VISUALIZATION

# %%
### matplotlib

# %%
import pandas as pd

# %%
# .plot

# %%
transactions = pd.read_csv("./transactions.csv")
transactions = transactions.head(10)

# %%
transactions.plot()
# Out:
# <Axes: >

# %%
transactions.set_index("date").plot()
# Out:
# <Axes: xlabel='date'>

# %%
transactions.plot(x="date", y="transactions");

# %% [markdown]
# # Assignment 1: Simple Line Chart
#
# Build a simple line plot for the oil series. Are there any interesting patterns here?
#
# What happened in 2014 to oil price?

# %%
oil = pd.read_csv("./oil.csv")
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
(oil
.astype({"date":"datetime64[ns]"})
.set_index("date")
.loc["2013":"2014"]
.plot())
# Out:
# <Axes: xlabel='date'>

# %%
transactions.plot(
    xlabel="date",
    title="Transactions",
    ylabel="date"
)
# Out:
# <Axes: title={'center': 'Transactions'}, xlabel='date', ylabel='date'>

# %%
transactions
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903
# 6  2013-01-02          6          2143
# 7  2013-01-02          7          1874
# 8  2013-01-02          8          3250
# 9  2013-01-02          9          2940

# %%
transactions.plot(
    xlabel="date",
    title="Transactions",
    ylabel="date",
    color="pink"
)
# Out:
# <Axes: title={'center': 'Transactions'}, xlabel='date', ylabel='date'>

# %%
transactions.plot(
    xlabel="date",
    title="Transactions",
    ylabel="Transactions",
    color=["pink","red"]
)
# Out:
# <Axes: title={'center': 'Transactions'}, xlabel='date', ylabel='Transactions'>

# %% [markdown]
# transactions.plot(
#     xlabel="date",
#     title="Transactions",
#     ylabel="date",
#     cmap="Pastel2"
# )

# %%
transactions.plot(
    xlabel="date",
    title="Transactions",
    ylabel="date",
    cmap="Pastel2"
)
# Out:
# <Axes: title={'center': 'Transactions'}, xlabel='date', ylabel='date'>

# %%
transactions.plot(
    xlabel="date",
    title="Transactions",
    ylabel="date",
    cmap="Pastel2",
    style=["--","-."]
)
# Out:
# <Axes: title={'center': 'Transactions'}, xlabel='date', ylabel='date'>

# %%
transactions.plot(
    xlabel="date",
    title="Transactions",
    ylabel="date",
    cmap="Pastel2",
    style=["--","-."],
    legend=False
)
# Out:
# <Axes: title={'center': 'Transactions'}, xlabel='date', ylabel='date'>

# %%
transactions.plot(
    xlabel="date",
    title="Transactions",
    ylabel="date",
    cmap="Pastel2",
    style=["--","-."]
).legend(loc="center right")

# %%
transactions.plot(
    xlabel="date",
    title="Transactions",
    ylabel="date",
    cmap="Pastel2",
    style=["--","-."]
).legend(bbox_to_anchor=(1,1));

# %%
transactions.plot(
    xlabel="date",
    title="Transactions",
    ylabel="date",
    cmap="Pastel2",
    style=["--","-."],
    legend=False,
    grid=True
)
# Out:
# <Axes: title={'center': 'Transactions'}, xlabel='date', ylabel='date'>

# %%
transactions.set_index("date").plot(subplots=True,grid="True")
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>], dtype=object)

# %%
transactions.set_index("date").plot(
    subplots=True,
    grid="True",
    layout=(1,2),
    title=["a","b"],
    figsize=(8,8)
)
# Out:
# array([[<Axes: title={'center': 'a'}, xlabel='date'>,
#         <Axes: title={'center': 'b'}, xlabel='date'>]], dtype=object)

# %%
transactions
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903
# 6  2013-01-02          6          2143
# 7  2013-01-02          7          1874
# 8  2013-01-02          8          3250
# 9  2013-01-02          9          2940

# %%
transactions.plot(
    kind="bar",
    rot=45
)
# Out:
# <Axes: >

# %%
transactions.plot.pie(y="transactions")
# Out:
# <Axes: ylabel='transactions'>

# %%
transactions.plot.scatter(y="transactions",x="date")
# Out:
# <Axes: xlabel='date', ylabel='transactions'>
