# %%
import pandas as pd

# %%
pd.DataFrame(
    {
        "id":[1,4],
        "store_nbr":[1,2],
        "transactions":[333,444]
    }
)
# Out:
#    id  store_nbr  transactions
# 0   1          1           333
# 1   4          2           444

# %%
oil = pd.read_csv("./oil.csv")
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.shape
# Out:
# (1218, 2)

# %%
oil.index
# Out:
# RangeIndex(start=0, stop=1218, step=1)

# %%
oil.columns
# Out:
# Index(['date', 'dcoilwtico'], dtype='object')

# %%
oil.axes
# Out:
# [RangeIndex(start=0, stop=1218, step=1),
#  Index(['date', 'dcoilwtico'], dtype='object')]

# %%
oil.dtypes
# Out:
# date           object
# dcoilwtico    float64
# dtype: object

# %%
oil.head(10)
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20
# 5  2013-01-08       93.21
# 6  2013-01-09       93.08
# 7  2013-01-10       93.81
# 8  2013-01-11       93.60
# 9  2013-01-14       94.27

# %%
oil.tail()
# Out:
#             date  dcoilwtico
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26

# %%
oil.sample(5, random_state=1234)
# Out:
#             date  dcoilwtico
# 886   2016-05-25       49.10
# 1043  2016-12-30       53.75
# 680   2015-08-11       43.11
# 601   2015-04-22       56.17
# 1206  2017-08-16       46.80

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
oil.describe(include="all").round(2)
# Out:
#               date  dcoilwtico
# count         1218     1175.00
# unique        1218         NaN
# top     2013-01-01         NaN
# freq             1         NaN
# mean           NaN       67.71
# std            NaN       25.63
# min            NaN       26.19
# 25%            NaN       46.40
# 50%            NaN       53.19
# 75%            NaN       95.66
# max            NaN      110.62

# %% [markdown]
# #### ACCESING DATAFRAME COLUMNS

# %%
oil.date
# Out:
# 0       2013-01-01
# 1       2013-01-02
# 2       2013-01-03
# 3       2013-01-04
# 4       2013-01-07
#            ...
# 1213    2017-08-25
# 1214    2017-08-28
# 1215    2017-08-29
# 1216    2017-08-30
# 1217    2017-08-31
# Name: date, Length: 1218, dtype: object

# %%
oil["date"]
# Out:
# 0       2013-01-01
# 1       2013-01-02
# 2       2013-01-03
# 3       2013-01-04
# 4       2013-01-07
#            ...
# 1213    2017-08-25
# 1214    2017-08-28
# 1215    2017-08-29
# 1216    2017-08-30
# 1217    2017-08-31
# Name: date, Length: 1218, dtype: object

# %%
oil["dcoilwtico"].mean()
# Out:
# 67.71436595744682

# %%
oil["dcoilwtico"].nunique()
# Out:
# 998

# %%
oil["dcoilwtico"].sum()
# Out:
# 79564.38

# %%
oil[["date","dcoilwtico"]].iloc[5:10]
# Out:
#          date  dcoilwtico
# 5  2013-01-08       93.21
# 6  2013-01-09       93.08
# 7  2013-01-10       93.81
# 8  2013-01-11       93.60
# 9  2013-01-14       94.27

# %%
oil.iloc[0:10,1:2]
# Out:
#    dcoilwtico
# 0         NaN
# 1       93.14
# 2       92.97
# 3       93.12
# 4       93.20
# 5       93.21
# 6       93.08
# 7       93.81
# 8       93.60
# 9       94.27

# %%
oil.loc[:,["date","dcoilwtico"]]
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %% [markdown]
# # Exercise 3 - Accessing DataFrames
#
# Hi, starting to dive deeper into this data.
#
# I noticed that the first row is the only one from 2013-01-01.
#
# * Can you get me a copy of the DataFrame that excludes that row, and only includes “store_nbr” and “transactions”?
# * Also, can you report the number of unique store numbers?
# * Finally, return the total number of transactions in millions

# %%
transactions = pd.read_csv("./transactions.csv")
transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
# skip the first row via slicing
transactions.loc[1:, "store_nbr":"transactions"]
# Out:
#        store_nbr  transactions
# 1              1          2111
# 2              2          2358
# 3              3          3487
# 4              4          1922
# 5              5          1903
# ...          ...           ...
# 83483         50          2804
# 83484         51          1573
# 83485         52          2255
# 83486         53           932
# 83487         54           802
#
# [83487 rows x 2 columns]

# %%
# calculate sum of store number column
transactions.loc[:,"store_nbr"].nunique()
# Out:
# 54

# %%
transactions.loc[:,"transactions"].sum() / 1000000
# Out:
# 141.478945

# %% [markdown]
# ### DROPPING ROWS & COLUMNS

# %%
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.drop("dcoilwtico", axis=1).head()
# Out:
#          date
# 0  2013-01-01
# 1  2013-01-02
# 2  2013-01-03
# 3  2013-01-04
# 4  2013-01-07

# %%
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
oil.drop([0], axis=0).head()
# Out:
#          date  dcoilwtico
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20
# 5  2013-01-08       93.21

# %%
oil.drop(range(5), axis=0).head()
# Out:
#          date  dcoilwtico
# 5  2013-01-08       93.21
# 6  2013-01-09       93.08
# 7  2013-01-10       93.81
# 8  2013-01-11       93.60
# 9  2013-01-14       94.27

# %% [markdown]
# ### IDENTIFYING DUPLICATE ROWS

# %%
products = pd.read_csv("./product.csv")
products
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# 3          FRUIT - SHELF STABLE                  APPLE SAUCE
# 4                 COOKIES/CONES            SPECIALTY COOKIES
# ...                         ...                          ...
# 92348                 BOOKSTORE              PAPERBACK BOOKS
# 92349                 BOOKSTORE            CHILDRENS LOW END
# 92350                 BOOKSTORE        PAPERBACK BEST SELLER
# 92351                 BOOKSTORE              PAPERBACK BOOKS
# 92352              PAPER TOWELS       PAPER TOWELS & HOLDERS
#
#       CURR_SIZE_OF_PRODUCT
# 0                    22 LB
# 1
# 2
# 3                    50 OZ
# 4                    14 OZ
# ...                    ...
# 92348
# 92349
# 92350
# 92351
# 92352
#
# [92353 rows x 7 columns]

# %%
products.shape
# Out:
# (92353, 7)

# %%
products.nunique()
# Out:
# PRODUCT_ID              92353
# MANUFACTURER             6476
# DEPARTMENT                 44
# BRAND                       2
# COMMODITY_DESC            308
# SUB_COMMODITY_DESC       2383
# CURR_SIZE_OF_PRODUCT     4345
# dtype: int64

# %%
list = products.iloc[:5,1:3]
list
# Out:
#    MANUFACTURER    DEPARTMENT
# 0             2       GROCERY
# 1             2  MISC. TRANS.
# 2            69        PASTRY
# 3            69       GROCERY
# 4            69       GROCERY

# %%
list.nunique()
# Out:
# MANUFACTURER    2
# DEPARTMENT      3
# dtype: int64

# %%
list.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
list.duplicated(subset="MANUFACTURER")
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
list.drop_duplicates()
# Out:
#    MANUFACTURER    DEPARTMENT
# 0             2       GROCERY
# 1             2  MISC. TRANS.
# 2            69        PASTRY
# 3            69       GROCERY

# %%
list.drop_duplicates(subset="MANUFACTURER",keep="last",ignore_index=True)
# Out:
#    MANUFACTURER    DEPARTMENT
# 0             2  MISC. TRANS.
# 1            69       GROCERY

# %% [markdown]
# # Assignment 4: Dropping Data and Duplicates
#
# Hi there!
#
# Can you:
#
# 1. Drop the first row of data? We want it permanently removed.
# 2. Drop the date column but not in place
# 3. Return a dataframe that only includes the last row for each of the stores.
#
# Thanks!

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.drop(0, axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 transactions.drop(0, axis=0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: '[0] not found in axis'

# %%
 transactions.head()
# Out:
#          date  store_nbr  transactions
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903

# %%
# drop date but not in place
transactions.drop("date", axis=1).head()
# Out:
#    store_nbr  transactions
# 1          1          2111
# 2          2          2358
# 3          3          3487
# 4          4          1922
# 5          5          1903

# %%
# drop duplicate rows subsetting by store number. keep last entry for each store
transactions.drop_duplicates(subset="store_nbr", keep="last").head()
# Out:
#              date  store_nbr  transactions
# 83434  2017-08-15          1          1693
# 83435  2017-08-15          2          1737
# 83436  2017-08-15          3          2956
# 83437  2017-08-15          4          1283
# 83438  2017-08-15          5          1310

# %% [markdown]
# ### IDENTIFYING MISSING DATA

# %%
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
new_oil = oil.fillna(0)

# %%
new_oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1218 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
oil.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1175 entries, 1 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1175 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 27.5+ KB

# %%
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.fillna({"dcoilwtico":0.5, "date":"2020-01-01"})
# Out:
#             date  dcoilwtico
# 0     2013-01-01        0.50
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %% [markdown]
# # Assignment 5: Missing Data
#
#
# Can you tell if any dates or prices are missing in the oil dataset?
#
# Then compare the mean of the oil series when filling in with mean vs. filling in with 0.
#
# Thanks!

# %% [markdown]
# ### FILTERING DATAFRAMES

# %%
oil.loc[oil["date"]=="2013-01-07"]
# Out:
#          date  dcoilwtico
# 4  2013-01-07        93.2

# %%
oil.loc[oil["date"]=="2013-01-07",["dcoilwtico","date"]]
# Out:
#    dcoilwtico        date
# 4        93.2  2013-01-07

# %%
products
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# 3          FRUIT - SHELF STABLE                  APPLE SAUCE
# 4                 COOKIES/CONES            SPECIALTY COOKIES
# ...                         ...                          ...
# 92348                 BOOKSTORE              PAPERBACK BOOKS
# 92349                 BOOKSTORE            CHILDRENS LOW END
# 92350                 BOOKSTORE        PAPERBACK BEST SELLER
# 92351                 BOOKSTORE              PAPERBACK BOOKS
# 92352              PAPER TOWELS       PAPER TOWELS & HOLDERS
#
#       CURR_SIZE_OF_PRODUCT
# 0                    22 LB
# 1
# 2
# 3                    50 OZ
# 4                    14 OZ
# ...                    ...
# 92348
# 92349
# 92350
# 92351
# 92352
#
# [92353 rows x 7 columns]

# %%
conds = products["DEPARTMENT"].isin(["GROCERY","DRUG GM"]) & (products["COMMODITY_DESC"].eq("BOOKSTORE"))
conds
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 92348     True
# 92349     True
# 92350     True
# 92351     True
# 92352    False
# Length: 92353, dtype: bool

# %%
products.loc[conds]
# Out:
#        PRODUCT_ID  MANUFACTURER DEPARTMENT     BRAND COMMODITY_DESC  \
# 314         36247           769    DRUG GM  National      BOOKSTORE
# 2136       107314           769    DRUG GM  National      BOOKSTORE
# 2639       151037          1580    DRUG GM  National      BOOKSTORE
# 5833       819267          5094    DRUG GM  National      BOOKSTORE
# 5888       819757          2737    DRUG GM  National      BOOKSTORE
# ...           ...           ...        ...       ...            ...
# 92329    18206211          6394    DRUG GM  National      BOOKSTORE
# 92348    18293142          6384    DRUG GM  National      BOOKSTORE
# 92349    18293439          6393    DRUG GM  National      BOOKSTORE
# 92350    18293696          6406    DRUG GM  National      BOOKSTORE
# 92351    18294080          6442    DRUG GM  National      BOOKSTORE
#
#                SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 314               PAPERBACK BOOKS
# 2136              PAPERBACK BOOKS
# 2639              PAPERBACK BOOKS
# 5833            CHILDRENS LOW END
# 5888              PAPERBACK BOOKS
# ...                           ...                  ...
# 92329  HARDBACK/TRADE BEST SELLER
# 92348             PAPERBACK BOOKS
# 92349           CHILDRENS LOW END
# 92350       PAPERBACK BEST SELLER
# 92351             PAPERBACK BOOKS
#
# [1134 rows x 7 columns]

# %% [markdown]
# ### PRO TIP: QUERY

# %%
products.query("DEPARTMENT in ['GROCERY','DRUG GM'] and COMMODITY_DESC == 'BOOKSTORE'")
# Out:
#        PRODUCT_ID  MANUFACTURER DEPARTMENT     BRAND COMMODITY_DESC  \
# 314         36247           769    DRUG GM  National      BOOKSTORE
# 2136       107314           769    DRUG GM  National      BOOKSTORE
# 2639       151037          1580    DRUG GM  National      BOOKSTORE
# 5833       819267          5094    DRUG GM  National      BOOKSTORE
# 5888       819757          2737    DRUG GM  National      BOOKSTORE
# ...           ...           ...        ...       ...            ...
# 92329    18206211          6394    DRUG GM  National      BOOKSTORE
# 92348    18293142          6384    DRUG GM  National      BOOKSTORE
# 92349    18293439          6393    DRUG GM  National      BOOKSTORE
# 92350    18293696          6406    DRUG GM  National      BOOKSTORE
# 92351    18294080          6442    DRUG GM  National      BOOKSTORE
#
#                SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 314               PAPERBACK BOOKS
# 2136              PAPERBACK BOOKS
# 2639              PAPERBACK BOOKS
# 5833            CHILDRENS LOW END
# 5888              PAPERBACK BOOKS
# ...                           ...                  ...
# 92329  HARDBACK/TRADE BEST SELLER
# 92348             PAPERBACK BOOKS
# 92349           CHILDRENS LOW END
# 92350       PAPERBACK BEST SELLER
# 92351             PAPERBACK BOOKS
#
# [1134 rows x 7 columns]

# %%
avg_size = products.loc[:, "MANUFACTURER"].mean()
avg_size
# Out:
# 1739.228330427815

# %%
products.query("DEPARTMENT in ['GROCERY','DRUG GM'] and MANUFACTURER > @avg_size")
# Out:
#        PRODUCT_ID  MANUFACTURER DEPARTMENT     BRAND  \
# 129         30317          5423    GROCERY  National
# 266         34747          2110    GROCERY  National
# 288         35407          1944    DRUG GM  National
# 296         35591          1837    GROCERY  National
# 350         37756          2193    GROCERY  National
# ...           ...           ...        ...       ...
# 92343    18273019          2223    GROCERY  National
# 92348    18293142          6384    DRUG GM  National
# 92349    18293439          6393    DRUG GM  National
# 92350    18293696          6406    DRUG GM  National
# 92351    18294080          6442    DRUG GM  National
#
#                   COMMODITY_DESC     SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 129       BAKED BREAD/BUNS/ROLLS           HOT DOG BUNS           10CT/17.5Z
# 266       ICE CREAM/MILK/SHERBTS          PREMIUM PINTS                 1 PT
# 288                HOSIERY/SOCKS                  LEGGS
# 296    VEGETABLES - SHELF STABLE           TOMATO SAUCE                15 OZ
# 350       ICE CREAM/MILK/SHERBTS                PREMIUM                48 OZ
# ...                          ...                    ...                  ...
# 92343                 BAG SNACKS   BAGGED CHEESE SNACKS              11.5 OZ
# 92348                  BOOKSTORE        PAPERBACK BOOKS
# 92349                  BOOKSTORE      CHILDRENS LOW END
# 92350                  BOOKSTORE  PAPERBACK BEST SELLER
# 92351                  BOOKSTORE        PAPERBACK BOOKS
#
# [20900 rows x 7 columns]

# %% [markdown]
# ### SORTING
# .sort_index() .sort_values()

# %% [markdown]
# ### RENAMING COLUMNS

# %%
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
oil.columns = ["DATE","DCOIL"]
oil.head()
# Out:
#          DATE  DCOIL
# 0  2013-01-01    NaN
# 1  2013-01-02  93.14
# 2  2013-01-03  92.97
# 3  2013-01-04  93.12
# 4  2013-01-07  93.20

# %%
oil
# Out:
#             DATE  DCOIL
# 0     2013-01-01    NaN
# 1     2013-01-02  93.14
# 2     2013-01-03  92.97
# 3     2013-01-04  93.12
# 4     2013-01-07  93.20
# ...          ...    ...
# 1213  2017-08-25  47.65
# 1214  2017-08-28  46.40
# 1215  2017-08-29  46.46
# 1216  2017-08-30  45.96
# 1217  2017-08-31  47.26
#
# [1218 rows x 2 columns]

# %%
oil.columns = [col.upper() for col in oil.columns]
oil
# Out:
#             DATE  DCOIL
# 0     2013-01-01    NaN
# 1     2013-01-02  93.14
# 2     2013-01-03  92.97
# 3     2013-01-04  93.12
# 4     2013-01-07  93.20
# ...          ...    ...
# 1213  2017-08-25  47.65
# 1214  2017-08-28  46.40
# 1215  2017-08-29  46.46
# 1216  2017-08-30  45.96
# 1217  2017-08-31  47.26
#
# [1218 rows x 2 columns]

# %%
oil.rename(columns={"DATE":"DDATE"}, inplace=True)
oil
# Out:
#            DDATE  DCOIL
# 0     2013-01-01    NaN
# 1     2013-01-02  93.14
# 2     2013-01-03  92.97
# 3     2013-01-04  93.12
# 4     2013-01-07  93.20
# ...          ...    ...
# 1213  2017-08-25  47.65
# 1214  2017-08-28  46.40
# 1215  2017-08-29  46.46
# 1216  2017-08-30  45.96
# 1217  2017-08-31  47.26
#
# [1218 rows x 2 columns]

# %%
oil.reindex(labels={"DCOIL","DDATE"},axis=1)
# Out:
#            DDATE  DCOIL
# 0     2013-01-01    NaN
# 1     2013-01-02  93.14
# 2     2013-01-03  92.97
# 3     2013-01-04  93.12
# 4     2013-01-07  93.20
# ...          ...    ...
# 1213  2017-08-25  47.65
# 1214  2017-08-28  46.40
# 1215  2017-08-29  46.46
# 1216  2017-08-30  45.96
# 1217  2017-08-31  47.26
#
# [1218 rows x 2 columns]

# %% [markdown]
# # Assignment 8: Modifying Columns
#
# Just some quick work, but can you send me the transaction data with the columns renamed?
#
# * Rename `transactions` to `transaction_count` and `store_nbr` to `store_number`.
# * Reorder the columns so date is first, then store number, then transaction count.
#
# Thanks!

# %%
oil
# Out:
#            DDATE  DCOIL
# 0     2013-01-01    NaN
# 1     2013-01-02  93.14
# 2     2013-01-03  92.97
# 3     2013-01-04  93.12
# 4     2013-01-07  93.20
# ...          ...    ...
# 1213  2017-08-25  47.65
# 1214  2017-08-28  46.40
# 1215  2017-08-29  46.46
# 1216  2017-08-30  45.96
# 1217  2017-08-31  47.26
#
# [1218 rows x 2 columns]

# %% [markdown]
# ### COLUMN CREATION

# %%
oil.head()
# Out:
#         DDATE  DCOIL
# 0  2013-01-01    NaN
# 1  2013-01-02  93.14
# 2  2013-01-03  92.97
# 3  2013-01-04  93.12
# 4  2013-01-07  93.20

# %%
oil["NEW_COL"] = oil["DCOIL"].mul(2)
oil.head()
# Out:
#         DDATE  DCOIL  NEW_COL
# 0  2013-01-01    NaN      NaN
# 1  2013-01-02  93.14   186.28
# 2  2013-01-03  92.97   185.94
# 3  2013-01-04  93.12   186.24
# 4  2013-01-07  93.20   186.40

# %%
oil["DCOIL_NAN"] = oil["DCOIL"].isna()
oil.head()
# Out:
#         DDATE  DCOIL  NEW_COL  DCOIL_NAN
# 0  2013-01-01    NaN      NaN       True
# 1  2013-01-02  93.14   186.28      False
# 2  2013-01-03  92.97   185.94      False
# 3  2013-01-04  93.12   186.24      False
# 4  2013-01-07  93.20   186.40      False

# %% [markdown]
# ### MAPPING VALUES TO COLUMNS

# %%
products
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# 3          FRUIT - SHELF STABLE                  APPLE SAUCE
# 4                 COOKIES/CONES            SPECIALTY COOKIES
# ...                         ...                          ...
# 92348                 BOOKSTORE              PAPERBACK BOOKS
# 92349                 BOOKSTORE            CHILDRENS LOW END
# 92350                 BOOKSTORE        PAPERBACK BEST SELLER
# 92351                 BOOKSTORE              PAPERBACK BOOKS
# 92352              PAPER TOWELS       PAPER TOWELS & HOLDERS
#
#       CURR_SIZE_OF_PRODUCT
# 0                    22 LB
# 1
# 2
# 3                    50 OZ
# 4                    14 OZ
# ...                    ...
# 92348
# 92349
# 92350
# 92351
# 92352
#
# [92353 rows x 7 columns]

# %%
mapping_dict = {"GROCERY":"G", "MISC. TRANS.":"MT", "DRUG GM":"DG","PASTRY":"P"}
products["SHORT_DEPT"] =products["DEPARTMENT"].map(mapping_dict)
products
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# 3          FRUIT - SHELF STABLE                  APPLE SAUCE
# 4                 COOKIES/CONES            SPECIALTY COOKIES
# ...                         ...                          ...
# 92348                 BOOKSTORE              PAPERBACK BOOKS
# 92349                 BOOKSTORE            CHILDRENS LOW END
# 92350                 BOOKSTORE        PAPERBACK BEST SELLER
# 92351                 BOOKSTORE              PAPERBACK BOOKS
# 92352              PAPER TOWELS       PAPER TOWELS & HOLDERS
#
#       CURR_SIZE_OF_PRODUCT SHORT_DEPT
# 0                    22 LB          G
# 1                                  MT
# 2                                   P
# 3                    50 OZ          G
# 4                    14 OZ          G
# ...                    ...        ...
# 92348                              DG
# 92349                              DG
# 92350                              DG
# 92351                              DG
# 92352                               G
#
# [92353 rows x 8 columns]

# %% [markdown]
# ### COLUMN CREATION WITH ASSIGN

# %%
new_products = products.assign(NEWMAN=products["MANUFACTURER"]*3)
new_products
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# 3          FRUIT - SHELF STABLE                  APPLE SAUCE
# 4                 COOKIES/CONES            SPECIALTY COOKIES
# ...                         ...                          ...
# 92348                 BOOKSTORE              PAPERBACK BOOKS
# 92349                 BOOKSTORE            CHILDRENS LOW END
# 92350                 BOOKSTORE        PAPERBACK BEST SELLER
# 92351                 BOOKSTORE              PAPERBACK BOOKS
# 92352              PAPER TOWELS       PAPER TOWELS & HOLDERS
#
#       CURR_SIZE_OF_PRODUCT SHORT_DEPT  NEWMAN
# 0                    22 LB          G       6
# 1                                  MT       6
# 2                                   P     207
# 3                    50 OZ          G     207
# 4                    14 OZ          G     207
# ...                    ...        ...     ...
# 92348                              DG   19152
# 92349                              DG   19179
# 92350                              DG   19218
# 92351                              DG   19326
# 92352                               G    2292
#
# [92353 rows x 9 columns]
